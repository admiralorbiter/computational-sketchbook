# %% [markdown]
# # 03: Longitudinal Capacity Trends (10-Year Panel)
#
# Evaluation of 10-year trends in student/teacher ratios, support staff allocations, and complexity metrics across the KC metro.
