# %% [markdown]
# # 01: Geographic Universe & Spatial Distribution
#
# Exploration of the Kansas City 9-county MARC study universe across NCES locale classifications (City, Suburb, Town, Rural) and distance from downtown.
